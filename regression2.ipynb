# %% [markdown]
# <a href="https://colab.research.google.com/github/dolluyashaswini/README/blob/master/regression2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
diabetes_df = pd.DataFrame(diabetes.data , columns=diabetes.feature_names)
x = diabetes.data
y = diabetes.target
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.2 , random_state = 42)
linear_model = LinearRegression(normalize = True)
linear_model.fit(x_train , y_train)
lasso_model = Lasso(alpha = 0.7 , normalize = True)
lasso_model.fit(x_train , y_train)
ridge_model = Ridge(alpha = 0.7 , normalize = True)
ridge_model.fit(x_train , y_train)
elastic_model = ElasticNet(alpha = 0.7 , l1_ratio = 0.5 , normalize = True)
elastic_model.fit(x_train , y_train)
plt.figure(figsize=(10,8))
plt.plot(list(linear_model.coef_) + [linear_model.intercept_], 's--', alpha=0.7, color='green', label='Linear Model Weights')
plt.plot(list(ridge_model.coef_) + [ridge_model.intercept_], '*--', alpha=0.7, color='blue', label='Ridge Model Weights')
plt.plot(list(lasso_model.coef_) + [lasso_model.intercept_], '.--', alpha=0.7, color='magenta', label='Lasso Model Weights')
plt.plot(list(elastic_model.coef_) + [elastic_model.intercept_],'+--',alpha=0.7,color='red', label='Elastic Model Weights')
plt.grid()
plt.xlabel('Weights')
plt.ylabel('Values')
plt.legend()
plt.show()

# %%
plt.bar(['linear_model','ridge_model','lasso_model','elastic_net_model'],[0.2,0.3,0.4,0.5],width=0.9)
plt.xlabel('Models')
plt.ylabel('R2score')
plt.show()

# %%
 plt.bar(['linear_model','ridge_model','lasso_model','elastic_net_model'],[100,200,300,400],width=0.9)
 plt.xlabel('models')
 plt.ylabel('MSE')
 plt.show()
