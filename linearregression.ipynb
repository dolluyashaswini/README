# %% [markdown]
# <a href="https://colab.research.google.com/github/dolluyashaswini/README/blob/master/linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
x,y = make_regression(n_samples=15,
                    bias=10,
                    n_features=1,
                    n_targets=1,
                    noise=4.0,
                    random_state=236)
plt.plot(x, y, '+')
plt.xlabel('Inputs (x)')
plt.ylabel('Outputs (y)')
plt.grid(True)
plt.show()
def linear_model(x, theta_0,theta_1):
  return np.sum(x * theta_1 + theta_0 , axis=1)
def MSE(y, y_hat):
  return np.sum((y-y_hat)**2) / len(y)
theta_0 , theta_1 = 1.0, -2.6
y_hat = linear_model(x, theta_0, theta_1)
plt.scatter(x, y)
plt.plot(x, y_hat)
plt.show()
def gradient_MSE(y, y_hat):
  grad_theta_1 = -2 * np.sum((y - y_hat) * x) / len(y)
  grad_theta_0 = -2 * np.sum((y - y_hat) * 1) / len(y)
  return grad_theta_0, grad_theta_1
def gradient_descent(x, y, theta_0, theta_1, epochs=30, eta=0.04):
  hist = {'loss': []}
  for i in range(epochs):
   y_hat = linear_model(x, theta_0, theta_1)
   curr_loss = MSE(y, y_hat)
   hist['loss'].append(curr_loss)
   grad_theta_0, grad_theta_1 = gradient_MSE(y, y_hat)
   theta_0 = theta_0 - eta * grad_theta_0
   theta_1 = theta_1 - eta * grad_theta_1
  return theta_0, theta_1, hist
theta_0, theta_1, hist = gradient_descent(x, y, theta_0, theta_1)
print(theta_0, theta_1)
plt.plot(hist['loss'], 'b-')
plt.plot(hist['loss'], 'r*')
plt.grid()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Change in loss during training')
plt.show()
y_hat = linear_model(x, theta_0, theta_1)
plt.scatter(x,y)
plt.plot(x,y_hat)
plt.show()
# Out:
# 13.272208782979574 45.31180496515293
